# %% [markdown]
# <a href="https://colab.research.google.com/github/gmccu73096/PortfolioProjects/blob/main/Movie_Correlation_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Import libraries

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #Adjusts the configuration of the plots we'll create.


# Read in the data
df = pd.read_csv(r'/content/drive/MyDrive/Data Analysis/other/movies.csv')
# Out:
# Mounted at /content/drive

# %%
# Let's look at the data

df.head()
# Out:
#                                              name  ... runtime
# 0                                     The Shining  ...   146.0
# 1                                 The Blue Lagoon  ...   104.0
# 2  Star Wars: Episode V - The Empire Strikes Back  ...   124.0
# 3                                       Airplane!  ...    88.0
# 4                                      Caddyshack  ...    98.0
#
# [5 rows x 15 columns]

# %%
# Let's see if there's any missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# Checking for null values
df.isna().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
# Getting rid of null values

df = df.dropna()

# %%
# Data types for our columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Change data types for budget, gross, and votes

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df['votes'] = df['votes'].astype('int64')

# %%
df.sort_values(by=['gross'],inplace = False, ascending = False)
# Out:
#                                             name  ... runtime
# 5445                                      Avatar  ...   162.0
# 7445                           Avengers: Endgame  ...   181.0
# 3045                                     Titanic  ...   194.0
# 6663  Star Wars: Episode VII - The Force Awakens  ...   138.0
# 7244                      Avengers: Infinity War  ...   149.0
# ...                                          ...  ...     ...
# 5640                                 Tanner Hall  ...    96.0
# 2434                  Philadelphia Experiment II  ...    97.0
# 3681                                Ginger Snaps  ...   108.0
# 272                                     Parasite  ...    85.0
# 3203                                  Trojan War  ...    85.0
#
# [5421 rows x 15 columns]

# %%
# Look at all the data

pd.set_option('display.max_rows', None)

# %%
# Drop duplicates

df['company'].drop_duplicates()
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 3330                          Zucker Brothers Productions
# 146                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 3698                              Zentropa Entertainments
# 1180                                 Zenith Entertainment
# 5180                                      Zazen Produções
# 1321                             Zanuck/Brown Productions
# 1329                          Zacharias-Buhai Productions
# 789                             Young Sung Production Co.
# 5125                           Young Hannibal Productions
# ...

# %%
df.head()
# Out:
#                                              name  ... runtime
# 0                                     The Shining  ...   146.0
# 1                                 The Blue Lagoon  ...   104.0
# 2  Star Wars: Episode V - The Empire Strikes Back  ...   124.0
# 3                                       Airplane!  ...    88.0
# 4                                      Caddyshack  ...    98.0
#
# [5 rows x 15 columns]

# %%
# Budget high correlation with gross?
# Company high correlation with gross?
# Director high correlation with gross?

# %%
# Scatter plot with budget vs. gross revenue


plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs. Gross Revenue')

plt.xlabel('Gross Revenue')
plt.ylabel('Film Budget')
plt.show()

# %%
# PLot budget vs. gross using seaborn

sns.regplot(x='budget', y='gross', data = df, scatter_kws={"color": "purple"}, line_kws={"color": "magenta"});

# %%
#Let's start looking at correlation

df.corr() #pearson, kendall, spearman
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
# High correlation between budget and gross confirmed

# %%
correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Numeric Features')
plt.ylabel('Numeric Features');

# %%
# Let's look at company - we'll convert nonnumeric variables into numeric variables for the sake of finding correlation

df_numerized = df

for col_name in df_numerized.columns:
  if(df_numerized[col_name].dtype == 'object'):
    df_numerized[col_name] = df_numerized[col_name].astype('category')
    df_numerized[col_name] = df_numerized[col_name].cat.codes # This assigns numbers to what before was an object **VERY USEFULL**

df_numerized.head()
# Out:
#    name  rating  genre  year  ...    budget      gross  company  runtime
# 0  4692       6      6  1980  ...  19000000   46998772     1426    146.0
# 1  3929       6      1  1980  ...   4500000   58853106      452    104.0
# 2  3641       4      0  1980  ...  18000000  538375067      945    124.0
# 3   204       4      4  1980  ...   3500000   83453539     1108     88.0
# 4   732       6      4  1980  ...   6000000   39846344     1083     98.0
#
# [5 rows x 15 columns]

# %%
correlation_matrix = df_numerized.corr()

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features');

# %%
correlation_matrix = df_numerized.corr()
# Out:
#               name    rating     genre  ...     gross   company   runtime
# name      1.000000 -0.029234  0.010996  ...  0.005639  0.021697  0.010850
# rating   -0.029234  1.000000  0.147796  ... -0.181906 -0.092357  0.140792
# genre     0.010996  0.147796  1.000000  ... -0.244101 -0.071334 -0.059237
# year      0.025542  0.019499 -0.073167  ...  0.274321 -0.014333  0.075077
# released -0.006152  0.018083  0.022142  ...  0.008501 -0.002407  0.008975
# score     0.014450  0.065983  0.035106  ...  0.222556  0.020656  0.414068
# votes     0.012615  0.006031 -0.135990  ...  0.614751  0.118470  0.352303
# director  0.015246  0.014656 -0.008553  ... -0.029560 -0.008223  0.017433
# writer    0.012880 -0.003149  0.017578  ... -0.035885 -0.003697 -0.017561
# star     -0.006882  0.009196  0.003341  ... -0.000004  0.014082  0.010108
# country  -0.025490  0.008230 -0.009164  ...  0.060078  0.048569 -0.034477
# budget    0.023392 -0.203946 -0.368523  ...  0.740247  0.170235  0.318695
# ...

# %%
sorted_pairs = corr_pairs.sort_values()

high_corr = sorted_pairs[(sorted_pairs) > 0.5] 

high_corr
# Out:
# votes     gross       0.614751
# gross     votes       0.614751
#           budget      0.740247
# budget    gross       0.740247
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %%
# Votes and budget have the highest correlation to gross earnings

# Company has low correlation
